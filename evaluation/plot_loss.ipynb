# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
lossf32 = np.loadtxt('/scratch2/vs488/flow/lars/experiments/glow_cifar10_cc_01/log/loss.csv', skiprows=1, delimiter=',')
lossm = np.loadtxt('/scratch2/vs488/flow/lars/experiments/glow_cifar10_cc_02/log/loss.csv', skiprows=1, delimiter=',')
lossf64 = np.loadtxt('/scratch2/vs488/flow/lars/experiments/glow_cifar10_cc_03/log/loss.csv', skiprows=1, delimiter=',')

# %%
lim = 1000
plt.plot(lossf32[:lim, 0], lossf32[:lim, 1])
#plt.plot(lossm[:lim, 0], lossm[:lim, 1])
plt.plot(lossf64[:lim, 0], lossf64[:lim, 1])
